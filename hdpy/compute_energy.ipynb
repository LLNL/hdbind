# %%
import pandas as pd

# %%
SEED=666

mlp_power = pd.read_csv("mlp_profile.csv")
hdc_power = pd.read_csv("hdc_profile.csv")

mlp_power = mlp_power.iloc[10000:30000]
hdc_power = hdc_power.iloc[2000:8000]


mlp_power_mean = (((mlp_power[mlp_power.apply(lambda x: x['index'] == 0, axis=1)])[' power.draw [W]']).apply(lambda x: float(x[:-2]))).mean()

hdc_power_mean = (((hdc_power[hdc_power.apply(lambda x: x['index'] == 0, axis=1)])[' power.draw [W]']).apply(lambda x: float(x[:-2]))).mean()

# %%
mlp_power_mean
# Out:
# 53.3948

# %%
import torch 
mlp_result = torch.load("results/666/mlp-1024-1.lit-pcba-ave-ADRB2-ave.666.pkl")
hdc_result = torch.load("results/666/hdbind-rp-molformer.lit-pcba-ave-ADRB2-ave.666.pkl")

# %%
mlp_result['trials'][0]
# Out:
# {'y_pred': array([0, 0, 0, ..., 0, 0, 0]),
#  'eta': array([[-7.211902e-05, -9.537080e+00],
#         [-7.211902e-05, -9.537080e+00],
#         [-7.211902e-05, -9.537080e+00],
#         ...,
#         [-7.211902e-05, -9.537080e+00],
#         [-7.211902e-05, -9.537080e+00],
#         [-7.211902e-05, -9.537080e+00]], dtype=float32),
#  'y_true': array([1, 1, 1, ..., 0, 0, 0]),
#  'train_time': 18.740610122680664,
#  'test_time': 0.26607275009155273,
#  'train_encode_time': None,
#  'test_encode_time': None,
#  'encode_time': None,
#  'train_size': 187501,
#  'test_size': 78124,
#  'class_report': '              precision    recall  f1-score   support\n\n           0       1.00      1.00      1.00     78120\n           1       0.00      0.00      0.00         4\n\n    accuracy                           1.00     78124\n   macro avg       0.50      0.50      0.50     78124\nweighted avg       1.00      1.00      1.00     78124\n',
#  'roc-auc': 0.5000064004096263}

# %%
hdc_result
# Out:
# {'trials': {0: {'hd_learning_curve': [array(77),
#     array(37),
#     array(25),
#     array(22),
#     array(22),
#     array(21),
#     array(21),
#     array(22),
#     array(19),
#     array(22)],
#    'am': {0: array([  693866,  -178494,  -856288, ..., -6296302, -4327708, -6223646]),
#     1: array([  384,    56, -1136, ..., -5330, -3294, -4878])},
#    'y_pred': array([[0],
#           [0],
#           [0],
#           ...,
#           [0],
#           [0],
#           [0]]),
#    'eta': array([[0.4991734 ],
#           [0.49935257],
#           [0.49895334],
#           ...,
#           [0.499251  ],
#           [0.49898514],
#           [0.49869883]], dtype=float32),
#    'y_true': array([[1],
#           [1],
#           [1],
#           ...,
#           [0],
#           [0],
#           [0]], dtype=int32),
#    'single_pass_train_time': None,
#    'test_time': 0.136397123336792,
#    'conf_test_time': 0.20930123329162598,
#    'train_encode_time': 0,
#    'test_encode_time': 0,
#    'encode_time': 0,
#    'class_report': '              precision    recall  f1-score   support\n\n           0       1.00      1.00      1.00     78120\n           1       0.00      0.00      0.00         4\n\n    accuracy                           1.00     78124\n   macro avg       0.50      0.50      0.50     78124\nweighted avg       1.00      1.00      1.00     78124\n',
#    'roc-auc': 0.5483630952380953},
#   1: {'hd_learning_curve': [array(38),
#     array(17),
#     array(21),
#     array(18),
#     array(18),
#     array(21),
#     array(14),
#     array(18),
#     array(19),
#     array(18)],
#    'am': {0: array([  725629,  -190749,  -886743, ..., -6527457, -4485083, -6451633]),
#     1: array([  401,    63, -1155, ..., -5357, -3311, -4905])},
#    'y_pred': array([[0],
#           [0],
#           [0],
#           ...,
#           [0],
#           [0],
#           [0]]),
#    'eta': array([[0.4991942 ],
#           [0.49935865],
#           [0.49905884],
#           ...,
#           [0.49929273],
#           [0.4990368 ],
#           [0.498737  ]], dtype=float32),
#    'y_true': array([[1],
#           [1],
#           [1],
#           ...,
#           [0],
#           [0],
#           [0]], dtype=int32),
#    'single_pass_train_time': None,
#    'test_time': 0.13283705711364746,
#    'conf_test_time': 0.20644736289978027,
#    'train_encode_time': 0,
#    'test_encode_time': 0,
#    'encode_time': 0,
#    'class_report': '              precision    recall  f1-score   support\n\n           0       1.00      1.00      1.00     78120\n           1       0.00      0.00      0.00         4\n\n    accuracy                           1.00     78124\n   macro avg       0.50      0.50      0.50     78124\nweighted avg       1.00      1.00      1.00     78124\n',
#    'roc-auc': 0.6193468381976447},
#   2: {'hd_learning_curve': [array(24),
#     array(10),
#     array(17),
#     array(9),
#     array(13),
#     array(6),
#     array(12),
#     array(7),
#     array(6),
#     array(4)],
#    'am': {0: array([  757406,  -202994,  -917202, ..., -6758618, -4642460, -6679626]),
#     1: array([  404,    60, -1170, ..., -5378, -3326, -4926])},
#    'y_pred': array([[0],
#           [0],
#           [0],
#           ...,
#           [0],
#           [0],
#           [0]]),
#    'eta': array([[0.49923456],
#           [0.4993554 ],
#           [0.49914268],
#           ...,
#           [0.4992982 ],
#           [0.49907327],
#           [0.49876964]], dtype=float32),
#    'y_true': array([[1],
#           [1],
#           [1],
#           ...,
#           [0],
#           [0],
#           [0]], dtype=int32),
#    'single_pass_train_time': None,
#    'test_time': 0.13065361976623535,
#    'conf_test_time': 0.19966888427734375,
#    'train_encode_time': 0,
#    'test_encode_time': 0,
#    'encode_time': 0,
#    'class_report': '              precision    recall  f1-score   support\n\n           0       1.00      1.00      1.00     78120\n           1       0.00      0.00      0.00         4\n\n    accuracy                           1.00     78124\n   macro avg       0.50      0.50      0.50     78124\nweighted avg       1.00      1.00      1.00     78124\n',
#    'roc-auc': 0.6864871351766513},
#   3: {'hd_learning_curve': [array(18),
#     array(2),
#     array(2),
#     array(4),
#     array(4),
#     array(4),
#     array(3),
#     array(1),
#     array(1),
#     array(1)],
#    'am': {0: array([  789187,  -215243,  -947663, ..., -6989793, -4799833, -6907633]),
#     1: array([  403,    61, -1183, ..., -5385, -3345, -4933])},
#    'y_pred': array([[0],
#           [0],
#           [0],
#           ...,
#           [0],
#           [0],
#           [0]]),
#    'eta': array([[0.49925575],
#           [0.4993639 ],
#           [0.49917763],
#           ...,
#           [0.4992908 ],
#           [0.49908066],
#           [0.49879438]], dtype=float32),
#    'y_true': array([[1],
#           [1],
#           [1],
#           ...,
#           [0],
#           [0],
#           [0]], dtype=int32),
#    'single_pass_train_time': None,
#    'test_time': 0.14089155197143555,
#    'conf_test_time': 0.2169327735900879,
#    'train_encode_time': 0,
#    'test_encode_time': 0,
#    'encode_time': 0,
#    'class_report': '              precision    recall  f1-score   support\n\n           0       1.00      1.00      1.00     78120\n           1       0.00      0.00      0.00         4\n\n    accuracy                           1.00     78124\n   macro avg       0.50      0.50      0.50     78124\nweighted avg       1.00      1.00      1.00     78124\n',
#    'roc-auc': 0.7280737967229903},
#   4: {'hd_learning_curve': [array(15),
#     array(1),
#     array(2),
#     array(1),
#     array(3),
#     array(0),
#     array(0),
#     array(0),
#     array(0),
#     array(0)],
#    'am': {0: array([  820968,  -227502,  -978132, ..., -7220974, -4957228, -7135646]),
#     1: array([  402,    72, -1188, ..., -5386, -3342, -4934])},
#    'y_pred': array([[0],
#           [0],
#           [0],
#           ...,
#           [0],
#           [0],
#           [0]]),
#    'eta': array([[0.49924475],
#           [0.49937153],
#           [0.4991789 ],
#           ...,
#           [0.4993016 ],
#           [0.4990958 ],
#           [0.49880144]], dtype=float32),
#    'y_true': array([[1],
#           [1],
#           [1],
#           ...,
#           [0],
#           [0],
#           [0]], dtype=int32),
#    'single_pass_train_time': None,
#    'test_time': 0.13523483276367188,
#    'conf_test_time': 0.20481419563293457,
#    'train_encode_time': 0,
#    'test_encode_time': 0,
#    'encode_time': 0,
#    'class_report': '              precision    recall  f1-score   support\n\n           0       1.00      1.00      1.00     78120\n           1       0.00      0.00      0.00         4\n\n    accuracy                           1.00     78124\n   macro avg       0.50      0.50      0.50     78124\nweighted avg       1.00      1.00      1.00     78124\n',
#    'roc-auc': 0.7315876216077829},
#   5: {'hd_learning_curve': [array(13),
#     array(0),
#     array(0),
#     array(0),
#     array(0),
#     array(0),
#     array(0),
#     array(0),
#     array(0),
#     array(0)],
#    'am': {0: array([  852746,  -239746, -1008598, ..., -7452156, -5114622, -7363658]),
#     1: array([  404,    68, -1196, ..., -5386, -3340, -4936])},
#    'y_pred': array([[0],
#           [0],
#           [0],
#           ...,
#           [0],
#           [0],
#           [0]]),
#    'eta': array([[0.49923748],
#           [0.4993671 ],
#           [0.49917716],
#           ...,
#           [0.49930155],
#           [0.49909487],
#           [0.49880385]], dtype=float32),
#    'y_true': array([[1],
#           [1],
#           [1],
#           ...,
#           [0],
#           [0],
#           [0]], dtype=int32),
#    'single_pass_train_time': None,
#    'test_time': 0.1350114345550537,
#    'conf_test_time': 0.19921255111694336,
#    'train_encode_time': 0,
#    'test_encode_time': 0,
#    'encode_time': 0,
#    'class_report': '              precision    recall  f1-score   support\n\n           0       1.00      1.00      1.00     78120\n           1       0.00      0.00      0.00         4\n\n    accuracy                           1.00     78124\n   macro avg       0.50      0.50      0.50     78124\nweighted avg       1.00      1.00      1.00     78124\n',
#    'roc-auc': 0.7236895161290322},
#   6: {'hd_learning_curve': [array(12),
#     array(0),
#     array(0),
#     array(0),
#     array(0),
#     array(0),
#     array(0),
#     array(0),
#     array(0),
#     array(0)],
#    'am': {0: array([  884521,  -251999, -1039067, ..., -7683337, -5272013, -7591671]),
#     1: array([  409,    73, -1201, ..., -5387, -3341, -4937])},
#    'y_pred': array([[0],
#           [0],
#           [0],
#           ...,
#           [0],
#           [0],
#           [0]]),
#    'eta': array([[0.49922928],
#           [0.49936765],
#           [0.499182  ],
#           ...,
#           [0.49930096],
#           [0.49908698],
#           [0.49881315]], dtype=float32),
#    'y_true': array([[1],
#           [1],
#           [1],
#           ...,
#           [0],
#           [0],
#           [0]], dtype=int32),
#    'single_pass_train_time': None,
#    'test_time': 0.13378238677978516,
#    'conf_test_time': 0.2026515007019043,
#    'train_encode_time': 0,
#    'test_encode_time': 0,
#    'encode_time': 0,
#    'class_report': '              precision    recall  f1-score   support\n\n           0       1.00      1.00      1.00     78120\n           1       0.00      0.00      0.00         4\n\n    accuracy                           1.00     78124\n   macro avg       0.50      0.50      0.50     78124\nweighted avg       1.00      1.00      1.00     78124\n',
#    'roc-auc': 0.7234479006656426},
#   7: {'hd_learning_curve': [array(11),
#     array(0),
#     array(0),
#     array(0),
#     array(0),
#     array(0),
#     array(0),
#     array(0),
#     array(0),
#     array(0)],
#    'am': {0: array([  916299,  -264245, -1069539, ..., -7914517, -5429401, -7819683]),
#     1: array([  411,    71, -1203, ..., -5389, -3345, -4939])},
#    'y_pred': array([[0],
#           [0],
#           [0],
#           ...,
#           [0],
#           [0],
#           [0]]),
#    'eta': array([[0.49921823],
#           [0.49935684],
#           [0.49917713],
#           ...,
#           [0.4992947 ],
#           [0.4990875 ],
#           [0.49882007]], dtype=float32),
#    'y_true': array([[1],
#           [1],
#           [1],
#           ...,
#           [0],
#           [0],
#           [0]], dtype=int32),
#    'single_pass_train_time': None,
#    'test_time': 0.13914752006530762,
#    'conf_test_time': 0.21318864822387695,
#    'train_encode_time': 0,
#    'test_encode_time': 0,
#    'encode_time': 0,
#    'class_report': '              precision    recall  f1-score   support\n\n           0       1.00      1.00      1.00     78120\n           1       0.00      0.00      0.00         4\n\n    accuracy                           1.00     78124\n   macro avg       0.50      0.50      0.50     78124\nweighted avg       1.00      1.00      1.00     78124\n',
#    'roc-auc': 0.7113143241167434},
#   8: {'hd_learning_curve': [array(14),
#     array(0),
#     array(0),
#     array(0),
#     array(0),
#     array(0),
#     array(0),
#     array(0),
#     array(0),
#     array(0)],
#    'am': {0: array([  948072,  -276490, -1100014, ..., -8145700, -5586792, -8047698]),
#     1: array([  418,    68, -1202, ..., -5388, -3346, -4938])},
#    'y_pred': array([[0],
#           [0],
#           [0],
#           ...,
#           [0],
#           [0],
#           [0]]),
#    'eta': array([[0.4992141 ],
#           [0.49936458],
#           [0.49918073],
#           ...,
#           [0.49929965],
#           [0.49909592],
#           [0.49881047]], dtype=float32),
#    'y_true': array([[1],
#           [1],
#           [1],
#           ...,
#           [0],
#           [0],
#           [0]], dtype=int32),
#    'single_pass_train_time': None,
#    'test_time': 0.13906192779541016,
#    'conf_test_time': 0.21338152885437012,
#    'train_encode_time': 0,
#    'test_encode_time': 0,
#    'encode_time': 0,
#    'class_report': '              precision    recall  f1-score   support\n\n           0       1.00      1.00      1.00     78120\n           1       0.00      0.00      0.00         4\n\n    accuracy                           1.00     78124\n   macro avg       0.50      0.50      0.50     78124\nweighted avg       1.00      1.00      1.00     78124\n',
#    'roc-auc': 0.7138792882744496},
#   9: {'hd_learning_curve': [array(13),
#     array(0),
#     array(0),
#     array(0),
#     array(0),
#     array(0),
#     array(0),
#     array(0),
#     array(0),
#     array(0)],
#    'am': {0: array([  979848,  -288734, -1130486, ..., -8376882, -5744184, -8275712]),
#     1: array([  422,    64, -1204, ..., -5388, -3346, -4938])},
#    'y_pred': array([[0],
#           [0],
#           [0],
#           ...,
#           [0],
#           [0],
#           [0]]),
#    'eta': array([[0.49920768],
#           [0.49935937],
#           [0.4991768 ],
#           ...,
#           [0.49930173],
#           [0.49909145],
#           [0.498815  ]], dtype=float32),
#    'y_true': array([[1],
#           [1],
#           [1],
#           ...,
#           [0],
#           [0],
#           [0]], dtype=int32),
#    'single_pass_train_time': None,
#    'test_time': 0.152113676071167,
#    'conf_test_time': 0.2392594814300537,
#    'train_encode_time': 0,
#    'test_encode_time': 0,
#    'encode_time': 0,
#    'class_report': '              precision    recall  f1-score   support\n\n           0       1.00      1.00      1.00     78120\n           1       0.00      0.00      0.00         4\n\n    accuracy                           1.00     78124\n   macro avg       0.50      0.50      0.50     78124\nweighted avg       1.00      1.00      1.00     78124\n',
#    'roc-auc': 0.706131592421915}},
#  'smiles_train': array(['CC(C)Nc1nc(NC(C)C)nc(n1)n2nc(C)cc2C',
#         'CC[C@@H]([NH2+]C(C)C)[C@@H](O)c1ccc(O)c2nc(O)ccc12',
#         'CCNc1nc(NCC)nc(n1)n2nc(C)cc2C', ...,
#         'Fc1ccc(CCNC(=O)C[NH+]2CCCCCC2)cc1',
#         'COCCn1nnnc1C[NH+]2CCC(O)(CC2)c3cccc(c3)C(F)(F)F',
#         'COCCn1nnnc1C[NH+]2CCC(Cc3ccccc3)CC2'], dtype=object),
#  'smiles_test': array(['CN(c1ccccc1)c2ccc(\\C=N\\NC(=O)CC#N)cc2',
#         'O=C1C[C@H](CC(=C1)[NH2+]C2CCCC2)c3ccccc3',
#         'CC1=NN(C(=S)N)C(=O)[C@@H]1N=Nc2ccc(F)cc2', ...,
#         'CCCCOC[C@@H](O)C[NH+]1CCN(CC1)C(=O)C',
#         'COc1ccc(cc1)C(=O)[C@H]([NH+]2CCOCC2)c3ccccc3',
#         'CCOCCC[NH2+]CC(=O)Nc1ccc(OC(F)(F)F)cc1'], dtype=object),
#  'y_train': array([1., 1., 1., ..., 0., 0., 0.]),
#  'y_test': array([1., 1., 1., ..., 0., 0., 0.]),
#  'args': Namespace(D=10000, device='cuda:0', ecfp_length=None, ecfp_radius=None, embedding='molformer', epochs=10, input_size=768, model='rp')}

# %%
mlp_time = ((mlp_result['trials'][0]['train_time'] / mlp_result['trials'][0]['train_size']) + \
                            (mlp_result['trials'][0]['test_time'] / mlp_result['trials'][0]['test_size'])) / 2
hdc_time = ((hdc_result['trials'][0]['train_time'] / hdc_result['trials'][0]['y_train'].shape[0]) + \
                            (hdc_result['trials'][0]['test_time'] / hdc_result['trials'][0]['y_test'].shape[0]))/ 2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [45], in <cell line: 3>()
#       1 mlp_time = ((mlp_result['trials'][0]['train_time'] / mlp_result['trials'][0]['train_size']) + \
#       2                             (mlp_result['trials'][0]['test_time'] / mlp_result['trials'][0]['test_size'])) / 2
# ----> 3 hdc_time = ((hdc_result['trials'][0]['train_time'] / hdc_result['trials'][0]['y_train'].shape[0]) + \
#       4                             (hdc_result['trials'][0]['test_time'] / hdc_result['trials'][0]['y_test'].shape[0]))/ 2
#
# KeyError: 'train_time'

# %%
mlp_power_mean * mlp_time
# Out:
# 14.20690127658844

# %%
hdc_time
# Out:
# 0.136397123336792

# %%
hdc_power_mean * hdc_time
# Out:
# 6.455031143794059
