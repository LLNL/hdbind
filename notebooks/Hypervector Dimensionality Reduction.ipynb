# %%
from pathlib import Path

# %%
hv_dir = "/g/g13/jones289/workspace/hd-cuda-master/hdpy/hdpy/.hd_cache"

# %%
import torch

# %%
hv = torch.load("/g/g13/jones289/workspace/hd-cuda-master/hdpy/hdpy/.hd_cache/selfies/bbbp/random/None-0-test_dataset_hv.pth")
hv.shape
# Out:
# torch.Size([513, 10000])

# %%
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# %%
pca_pipe = make_pipeline(StandardScaler(), PCA())

# %%
pca_pipe.fit(hv)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()), ('pca', PCA())])

# %%
comps = pca_pipe.transform(hv)

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
sns.scatterplot(comps[:, 0], comps[:, 1])
# Out:
# /usr/workspace/wsa/jones289/miniconda3/envs/dtra_reactivator/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>
